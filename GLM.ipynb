# %%
import os, sys
import kagglehub
import numpy as np
import pandas as pd
# Download latest version
path = kagglehub.dataset_download("kadiryildirim12/u-s-chronic-disease-indicators-cdi-2023-release")

print("Path to dataset files:", path)

os.listdir(path)

cdi_df = pd.read_csv(os.path.join(
    path,
    'U.S._Chronic_Disease_Indicators__CDI___2023_Release.csv')
    )

TOPICS = ['Chronic Obstructive Pulmonary Disease', 'Asthma', 'Cardiovascular Disease', 'Tobacco']
for topic in TOPICS:
    topic_formatted = topic.lower().replace(' ', '_')
    cdi_df.loc[cdi_df['Topic'] == topic, :].to_csv(f'{topic_formatted}.csv', index=False)
# Out:
# ...
# Path to dataset files: /Users/yeonsookim/.cache/kagglehub/datasets/kadiryildirim12/u-s-chronic-disease-indicators-cdi-2023-release/versions/1
# /var/folders/3r/zljmfgh13vj0qjr8z8xyhxh40000gn/T/ipykernel_7524/2584859269.py:12: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdi_df = pd.read_csv(os.path.join(

# %%
cdi_df
# Out:
#          YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0             2014     2014           AR              Arkansas  SEDD; SID
# 1             2018     2018           CO              Colorado  SEDD; SID
# 2             2018     2018           DC  District of Columbia  SEDD; SID
# 3             2017     2017           GA               Georgia  SEDD; SID
# 4             2010     2010           MI              Michigan  SEDD; SID
# ...            ...      ...          ...                   ...        ...
# 1185671       2020     2020           WY               Wyoming      BRFSS
# 1185672       2020     2020           WY               Wyoming      BRFSS
# 1185673       2017     2017           IA                  Iowa      BRFSS
# 1185674       2020     2020           WY               Wyoming      BRFSS
# 1185675       2019     2019           RI          Rhode Island      BRFSS
#
#                 Topic                                           Question  \
# ...

# %%
asthma = cdi_df[cdi_df['Topic'] == "Asthma"]
asthma
# Out:
#          YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0             2014     2014           AR              Arkansas  SEDD; SID
# 1             2018     2018           CO              Colorado  SEDD; SID
# 2             2018     2018           DC  District of Columbia  SEDD; SID
# 3             2017     2017           GA               Georgia  SEDD; SID
# 4             2010     2010           MI              Michigan  SEDD; SID
# ...            ...      ...          ...                   ...        ...
# 1185511       2020     2020           WY               Wyoming      BRFSS
# 1185519       2020     2020           WY               Wyoming      BRFSS
# 1185570       2020     2020           WY               Wyoming      BRFSS
# 1185633       2020     2020           WY               Wyoming      BRFSS
# 1185654       2020     2020           WY               Wyoming      BRFSS
#
#           Topic                                           Question  Response  \
# ...

# %%
asthma['YearStart'].unique()
# Out:
# array([2014, 2018, 2017, 2010, 2015, 2013, 2016, 2020, 2012, 2019, 2011,
#        2021])

# %%
asthma_2014 = asthma[(asthma['YearStart'] == 2014) & (asthma['YearEnd'] == 2014)]
asthma_2014
# Out:
#          YearStart  YearEnd LocationAbbr    LocationDesc DataSource   Topic  \
# 0             2014     2014           AR        Arkansas  SEDD; SID  Asthma
# 11            2014     2014           AL         Alabama       NVSS  Asthma
# 21            2014     2014           MD        Maryland       NVSS  Asthma
# 24            2014     2014           NC  North Carolina       NVSS  Asthma
# 184           2014     2014           ID           Idaho       NVSS  Asthma
# ...            ...      ...          ...             ...        ...     ...
# 1181619       2014     2014           WY         Wyoming      BRFSS  Asthma
# 1181633       2014     2014           WY         Wyoming      BRFSS  Asthma
# 1181758       2014     2014           WY         Wyoming      BRFSS  Asthma
# 1181896       2014     2014           WY         Wyoming      BRFSS  Asthma
# 1181940       2014     2014           WY         Wyoming      BRFSS  Asthma
#
# ...

# %%
asthma_2015 = asthma[(asthma['YearStart'] == 2015) & (asthma['YearEnd'] == 2015)]
asthma_2016 = asthma[(asthma['YearStart'] == 2016) & (asthma['YearEnd'] == 2016)]
asthma_2017 = asthma[(asthma['YearStart'] == 2017) & (asthma['YearEnd'] == 2017)]
asthma_2018 = asthma[(asthma['YearStart'] == 2018) & (asthma['YearEnd'] == 2018)]
asthma_2019 = asthma[(asthma['YearStart'] == 2019) & (asthma['YearEnd'] == 2019)]
asthma_2020 = asthma[(asthma['YearStart'] == 2020) & (asthma['YearEnd'] == 2020)]
asthma_2021 = asthma[(asthma['YearStart'] == 2021) & (asthma['YearEnd'] == 2021)]
asthma_2021
# Out:
#          YearStart  YearEnd LocationAbbr LocationDesc DataSource   Topic  \
# 529341        2021     2021           AL      Alabama      BRFSS  Asthma
# 529360        2021     2021           KS       Kansas      BRFSS  Asthma
# 529394        2021     2021           VA     Virginia      BRFSS  Asthma
# 529649        2021     2021           AK       Alaska      BRFSS  Asthma
# 529706        2021     2021           AL      Alabama      BRFSS  Asthma
# ...            ...      ...          ...          ...        ...     ...
# 1182019       2021     2021           WY      Wyoming      BRFSS  Asthma
# 1182131       2021     2021           WY      Wyoming      BRFSS  Asthma
# 1182133       2021     2021           WY      Wyoming      BRFSS  Asthma
# 1182260       2021     2021           WY      Wyoming      BRFSS  Asthma
# 1182482       2021     2021           WY      Wyoming      BRFSS  Asthma
#
#                                                   Question  Response  \
# ...

# %%
# import pandas as pd
# import requests

# # url = "https://data.cdc.gov/resource/fcqm-xrf4.csv?$query=SELECT%0A%20%20%60year%60%2C%0A%20%20%60date%60%2C%0A%20%20%60statefips%60%2C%0A%20%20%60countyfips%60%2C%0A%20%20%60ctfips%60%2C%0A%20%20%60latitude%60%2C%0A%20%20%60longitude%60%2C%0A%20%20%60ds_pm_pred%60%2C%0A%20%20%60ds_pm_stdd%60%0AWHERE%20caseless_one_of(%60year%60%2C%20%222014%22)"
# url = "https://data.cdc.gov/resource/fcqm-xrf4.csv?$query=SELECT%0A%20%20%60year%60%2C%0A%20%20%60date%60%2C%0A%20%20%60statefips%60%2C%0A%20%20%60countyfips%60%2C%0A%20%20%60ctfips%60%2C%0A%20%20%60latitude%60%2C%0A%20%20%60longitude%60%2C%0A%20%20%60ds_pm_pred%60%2C%0A%20%20%60ds_pm_stdd%60%0AWHERE%0A%20%20caseless_one_of(%60year%60%2C%20%222014%22)%20AND%20caseless_one_of(%60statefips%60%2C%20%221%22)"
# response = requests.get(url)

# if response.status_code == 200:
#     from io import StringIO
#     data = StringIO(response.text)
#     pm_2014 = pd.read_csv(data)
    
#     # Display the first few rows of the DataFrame
#     print(pm_2014.head())
# else:
#     print(f"Failed to fetch data. Status code: {response.status_code}")

# %%
pm_2014 = pd.read_csv("Daily_Census_Tract-Level_PM2.5_Concentrations__2014.csv")

# %%
pm_2014
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2014  01JAN2014         12       12087  12087972600  24.54941
# 1         2014  01JAN2014         12       12087  12087972400  24.55265
# 2         2014  01JAN2014         12       12087  12087972300  24.55602
# 3         2014  01JAN2014         12       12087  12087972000  24.55621
# 4         2014  01JAN2014         12       12087  12087972200  24.55726
# ...        ...        ...        ...         ...          ...       ...
# 26383290  2014  31DEC2014         53       53073  53073010403  48.95131
# 26383291  2014  31DEC2014         53       53073  53073010301  48.95540
# 26383292  2014  31DEC2014         53       53073  53073010401  48.97138
# 26383293  2014  31DEC2014         53       53073  53073010303  48.97593
# 26383294  2014  31DEC2014         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd
# 0         -81.79179      9.9932      9.6032
# ...

# %%
pm_2014.columns
# Out:
# Index(['year', 'date', 'statefips', 'countyfips', 'ctfips', 'latitude',
#        'longitude', 'ds_pm_pred', 'ds_pm_stdd'],
#       dtype='object')

# %%
asthma_2014['LocationDesc'].unique()
# Out:
# array(['Arkansas', 'Alabama', 'Maryland', 'North Carolina', 'Idaho',
#        'Kansas', 'Massachusetts', 'Alaska', 'Wisconsin', 'Nevada',
#        'California', 'West Virginia', 'New Hampshire', 'Connecticut',
#        'Puerto Rico', 'Virgin Islands', 'Guam', 'Vermont', 'Colorado',
#        'Oregon', 'New Mexico', 'Delaware', 'Illinois', 'Pennsylvania',
#        'Kentucky', 'Florida', 'Rhode Island', 'Virginia',
#        'South Carolina', 'Texas', 'New York', 'New Jersey',
#        'North Dakota', 'Louisiana', 'Maine', 'Missouri', 'Ohio',
#        'Mississippi', 'Michigan', 'District of Columbia', 'Arizona',
#        'Hawaii', 'Montana', 'Indiana', 'Minnesota', 'Oklahoma',
#        'South Dakota', 'Iowa', 'Utah', 'Wyoming', 'Nebraska', 'Tennessee',
#        'Georgia', 'Washington', 'United States'], dtype=object)

# %%
pm_2014['statefips']
# Out:
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12
#             ..
# 26383290    53
# 26383291    53
# 26383292    53
# 26383293    53
# 26383294    53
# Name: statefips, Length: 26383295, dtype: int64

# %%
asthma_2014.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
state_fips = {
    1: 'Alabama',
    2: 'Alaska',
    4: 'Arizona',
    5: 'Arkansas',
    6: 'California',
    8: 'Colorado',
    9: 'Connecticut',
    10: 'Delaware',
    11: 'District of Columbia',
    12: 'Florida',
    13: 'Georgia',
    15: 'Hawaii',
    16: 'Idaho',
    17: 'Illinois',
    18: 'Indiana',
    19: 'Iowa',
    20: 'Kansas',
    21: 'Kentucky',
    22: 'Louisiana',
    23: 'Maine',
    24: 'Maryland',
    25: 'Massachusetts',
    26: 'Michigan',
    27: 'Minnesota',
    28: 'Mississippi',
    29: 'Missouri',
    30: 'Montana',
    31: 'Nebraska',
    32: 'Nevada',
    33: 'New Hampshire',
    34: 'New Jersey',
    35: 'New Mexico',
    36: 'New York',
    37: 'North Carolina',
    38: 'North Dakota',
    39: 'Ohio',
    40: 'Oklahoma',
    41: 'Oregon',
    42: 'Pennsylvania',
    44: 'Rhode Island',
    45: 'South Carolina',
    46: 'South Dakota',
    47: 'Tennessee',
    48: 'Texas',
    49: 'Utah',
    50: 'Vermont',
    51: 'Virginia',
    53: 'Washington',
    54: 'West Virginia',
    55: 'Wisconsin',
    56: 'Wyoming'
}

# %%
pm_2011 = pd.read_csv("Daily_Census_Tract-Level_PM2.5_Concentrations__2011.csv")
pm_2011
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2011  16JAN2011         36       36067  36067016802  42.86482
# 1         2011  16JAN2011         36       36067  36067016901  42.81138
# 2         2011  16JAN2011         36       36067  36067016902  42.82194
# 3         2011  16JAN2011         36       36067  36067940000  42.94020
# 4         2011  16JAN2011         36       36069  36069050101  43.00244
# ...        ...        ...        ...         ...          ...       ...
# 26383290  2011  16JAN2011         36       36067  36067016501  42.93499
# 26383291  2011  16JAN2011         36       36067  36067016502  42.98960
# 26383292  2011  16JAN2011         36       36067  36067016600  42.97702
# 26383293  2011  16JAN2011         36       36067  36067016700  42.89961
# 26383294  2011  16JAN2011         36       36067  36067016801  42.83458
#
#           longitude  ds_pm_pred  ds_pm_stdd
# 0         -76.22294    7.163089    4.463915
# ...

# %%
pm_2012 = pd.read_csv("Daily_Census_Tract-Level_PM2.5_Concentrations__2012.csv")
pm_2012
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2012  01JAN2012         12       12087  12087972600  24.54941
# 1         2012  01JAN2012         12       12087  12087972400  24.55265
# 2         2012  01JAN2012         12       12087  12087972300  24.55602
# 3         2012  01JAN2012         12       12087  12087972000  24.55621
# 4         2012  01JAN2012         12       12087  12087972200  24.55726
# ...        ...        ...        ...         ...          ...       ...
# 26455573  2012  31DEC2012         53       53073  53073010403  48.95131
# 26455574  2012  31DEC2012         53       53073  53073010301  48.95540
# 26455575  2012  31DEC2012         53       53073  53073010401  48.97138
# 26455576  2012  31DEC2012         53       53073  53073010303  48.97593
# 26455577  2012  31DEC2012         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd
# 0         -81.79179     13.0316      8.2153
# ...

# %%
pm_2013 = pd.read_csv("Daily_Census_Tract-Level_PM2.5_Concentrations__2013.csv")
pm_2013
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2012  01JAN2012         12       12087  12087972600  24.54941
# 1         2012  01JAN2012         12       12087  12087972400  24.55265
# 2         2012  01JAN2012         12       12087  12087972300  24.55602
# 3         2012  01JAN2012         12       12087  12087972000  24.55621
# 4         2012  01JAN2012         12       12087  12087972200  24.55726
# ...        ...        ...        ...         ...          ...       ...
# 26455573  2012  31DEC2012         53       53073  53073010403  48.95131
# 26455574  2012  31DEC2012         53       53073  53073010301  48.95540
# 26455575  2012  31DEC2012         53       53073  53073010401  48.97138
# 26455576  2012  31DEC2012         53       53073  53073010303  48.97593
# 26455577  2012  31DEC2012         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd
# 0         -81.79179     13.0316      8.2153
# ...

# %%
pm_2014['LocationDesc'] = pm_2014['statefips'].map(state_fips)
pm_2014
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2014  01JAN2014         12       12087  12087972600  24.54941
# 1         2014  01JAN2014         12       12087  12087972400  24.55265
# 2         2014  01JAN2014         12       12087  12087972300  24.55602
# 3         2014  01JAN2014         12       12087  12087972000  24.55621
# 4         2014  01JAN2014         12       12087  12087972200  24.55726
# ...        ...        ...        ...         ...          ...       ...
# 26383290  2014  31DEC2014         53       53073  53073010403  48.95131
# 26383291  2014  31DEC2014         53       53073  53073010301  48.95540
# 26383292  2014  31DEC2014         53       53073  53073010401  48.97138
# 26383293  2014  31DEC2014         53       53073  53073010303  48.97593
# 26383294  2014  31DEC2014         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd LocationDesc
# ...

# %%
pm_2014['statefips'].unique()
# Out:
# array([12, 48, 22,  1, 28, 13,  4, 35, 45,  6,  5, 40, 37, 47, 32, 29, 21,
#        51, 17, 20, 49,  8, 54, 18, 24, 39, 10, 11, 34, 42, 31, 19, 36,  9,
#        56, 44, 25, 26, 41, 16, 55, 46, 33, 50, 23, 27, 30, 53, 38])

# %%
pm_2014['LocationDesc'].unique()
# Out:
# array(['Florida', 'Texas', 'Louisiana', 'Alabama', 'Mississippi',
#        'Georgia', 'Arizona', 'New Mexico', 'South Carolina', 'California',
#        'Arkansas', 'Oklahoma', 'North Carolina', 'Tennessee', 'Nevada',
#        'Missouri', 'Kentucky', 'Virginia', 'Illinois', 'Kansas', 'Utah',
#        'Colorado', 'West Virginia', 'Indiana', 'Maryland', 'Ohio',
#        'Delaware', 'District of Columbia', 'New Jersey', 'Pennsylvania',
#        'Nebraska', 'Iowa', 'New York', 'Connecticut', 'Wyoming',
#        'Rhode Island', 'Massachusetts', 'Michigan', 'Oregon', 'Idaho',
#        'Wisconsin', 'South Dakota', 'New Hampshire', 'Vermont', 'Maine',
#        'Minnesota', 'Montana', 'Washington', 'North Dakota'], dtype=object)

# %%
pm_2014
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2014  01JAN2014         12       12087  12087972600  24.54941
# 1         2014  01JAN2014         12       12087  12087972400  24.55265
# 2         2014  01JAN2014         12       12087  12087972300  24.55602
# 3         2014  01JAN2014         12       12087  12087972000  24.55621
# 4         2014  01JAN2014         12       12087  12087972200  24.55726
# ...        ...        ...        ...         ...          ...       ...
# 26383290  2014  31DEC2014         53       53073  53073010403  48.95131
# 26383291  2014  31DEC2014         53       53073  53073010301  48.95540
# 26383292  2014  31DEC2014         53       53073  53073010401  48.97138
# 26383293  2014  31DEC2014         53       53073  53073010303  48.97593
# 26383294  2014  31DEC2014         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd LocationDesc
# ...

# %%
# pm = pd.concat([pm_2011, pm_2012, pm_2013, pm_2014], axis=1)
pm = pd.concat([pm_2011, pm_2012, pm_2013, pm_2014])
pm
# Out:
#           year       date  statefips  countyfips       ctfips  latitude  \
# 0         2011  16JAN2011         36       36067  36067016802  42.86482
# 1         2011  16JAN2011         36       36067  36067016901  42.81138
# 2         2011  16JAN2011         36       36067  36067016902  42.82194
# 3         2011  16JAN2011         36       36067  36067940000  42.94020
# 4         2011  16JAN2011         36       36069  36069050101  43.00244
# ...        ...        ...        ...         ...          ...       ...
# 26383290  2014  31DEC2014         53       53073  53073010403  48.95131
# 26383291  2014  31DEC2014         53       53073  53073010301  48.95540
# 26383292  2014  31DEC2014         53       53073  53073010401  48.97138
# 26383293  2014  31DEC2014         53       53073  53073010303  48.97593
# 26383294  2014  31DEC2014         53       53073  53073011000  48.98832
#
#           longitude  ds_pm_pred  ds_pm_stdd LocationDesc
# ...

# %%
pm_data = {
    'year': [2011, 2012, 2013, 2014],
    'avg_pm': [(np.sum(pm_2011['ds_pm_pred'])/len(pm_2011)), (np.sum(pm_2012['ds_pm_pred'])/len(pm_2012)), (np.sum(pm_2013['ds_pm_pred'])/len(pm_2013)), (np.sum(pm_2014['ds_pm_pred'])/len(pm_2014))]
    
}
pm_year = pd.DataFrame(pm_data)
pm_year
# Out:
#    year    avg_pm
# 0  2011  9.771093
# 1  2012  9.311493
# 2  2013  9.311493
# 3  2014  9.517065

# %%
top_loc = pm_2014['LocationDesc'].value_counts().nlargest(3) 

print(top_loc)
# Out:
# LocationDesc
# California    2934600
# Texas         1917710
# New York      1788865
# Name: count, dtype: int64

# %%
asthma_2014.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
top_loc = asthma_2017['LocationDesc'].value_counts().nlargest(3) 

print(top_loc)
# Out:
# LocationDesc
# Georgia         158
# Pennsylvania    158
# Virginia        158
# Name: count, dtype: int64

# %%
top_loc = asthma_2017['LocationDesc'].value_counts()

print(top_loc)
# Out:
# LocationDesc
# Georgia                 158
# Pennsylvania            158
# Virginia                158
# Rhode Island            158
# Hawaii                  158
# Minnesota               158
# Connecticut             158
# Colorado                158
# Tennessee               158
# New Hampshire           158
# District of Columbia    158
# Missouri                158
# Oklahoma                158
# Delaware                158
# West Virginia           158
# Nevada                  158
# Wisconsin               158
# Texas                   158
# Vermont                 158
# North Carolina          158
# North Dakota            158
# South Dakota            158
# Iowa                    158
# Nebraska                158
# South Carolina          158
# Michigan                158
# Ohio                    158
# Idaho                   158
# Maryland                158
# New York                158
# Washington              158
# Maine                   158
# ...

# %%
asthma_2014_copy = asthma_2014.copy()
asthma_2014_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2014_copy['DataValue'], errors='coerce')
asthma_2014_val = asthma_2014_copy['DataValue'].dropna()
asthma_2014_average_val = np.sum(asthma_2014_val) / len(asthma_2014_val)

print(asthma_2014_average_val)
# Out:
# 540.4292033856111

# %%
asthma_2015_copy = asthma_2015.copy()
asthma_2015_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2015_copy['DataValue'], errors='coerce')
asthma_2015_val = asthma_2015_copy['DataValue'].dropna()
asthma_2015_average_val = np.sum(asthma_2015_val) / len(asthma_2015_val)

asthma_2016_copy = asthma_2016.copy()
asthma_2016_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2016_copy['DataValue'], errors='coerce')
asthma_2016_val = asthma_2016_copy['DataValue'].dropna()
asthma_2016_average_val = np.sum(asthma_2016_val) / len(asthma_2016_val)

asthma_2017_copy = asthma_2017.copy()
asthma_2017_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2017_copy['DataValue'], errors='coerce')
asthma_2017_val = asthma_2017_copy['DataValue'].dropna()
asthma_2017_average_val = np.sum(asthma_2017_val) / len(asthma_2017_val)

asthma_2018_copy = asthma_2018.copy()
asthma_2018_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2018_copy['DataValue'], errors='coerce')
asthma_2018_val = asthma_2018_copy['DataValue'].dropna()
asthma_2018_average_val = np.sum(asthma_2018_val) / len(asthma_2018_val)

asthma_2019_copy = asthma_2019.copy()
asthma_2019_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2019_copy['DataValue'], errors='coerce')
asthma_2019_val = asthma_2019_copy['DataValue'].dropna()
asthma_2019_average_val = np.sum(asthma_2019_val) / len(asthma_2019_val)

asthma_2020_copy = asthma_2020.copy()
asthma_2020_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2020_copy['DataValue'], errors='coerce')
asthma_2020_val = asthma_2020_copy['DataValue'].dropna()
asthma_2020_average_val = np.sum(asthma_2020_val) / len(asthma_2020_val)

asthma_2021_copy = asthma_2021.copy()
asthma_2021_copy.loc[:, 'DataValue'] = pd.to_numeric(asthma_2021_copy['DataValue'], errors='coerce')
asthma_2021_val = asthma_2021_copy['DataValue'].dropna()
asthma_2021_average_val = np.sum(asthma_2021_val) / len(asthma_2021_val)

# %%
asthma_data = {
    'year': [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
    'asthma_count': [asthma_2014_average_val, asthma_2015_average_val, asthma_2016_average_val, asthma_2017_average_val, asthma_2018_average_val, \
                    asthma_2019_average_val, asthma_2020_average_val, asthma_2021_average_val]
}
asthma_year = pd.DataFrame(asthma_data)
asthma_year
# Out:
#    year  asthma_count
# 0  2014    540.429203
# 1  2015    372.054824
# 2  2016    489.767217
# 3  2017    396.174372
# 4  2018    397.839532
# 5  2019     41.619829
# 6  2020     42.345748
# 7  2021     41.508959

# %%
three_year = pd.DataFrame({'avg_pm':pm_year[0:3]['avg_pm'], 'asthma_count': asthma_year[0:3]['asthma_count']})
three_year
# Out:
#      avg_pm  asthma_count
# 0  9.771093    540.429203
# 1  9.311493    372.054824
# 2  9.311493    489.767217

# %%
import statsmodels.api as sm
import pandas as pd

X = three_year[['avg_pm']] 
X = sm.add_constant(X)

y = three_year['asthma_count'] 

freq_model = sm.GLM(y, exog = X, 
                  family=sm.families.Poisson())
freq_res = freq_model.fit()
print(freq_res.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           asthma_count   No. Observations:                    3
# Model:                            GLM   Df Residuals:                        1
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20.024
# Date:                Sat, 14 Dec 2024   Deviance:                       16.128
# Time:                        14:57:23   Pearson chi2:                     16.1
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.9962
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4778      1.133      1.304      0.192      -0.743       3.699
# ...

# %%
sel_as = asthma_year[4:7].reset_index()
seven_year = pd.DataFrame({'avg_pm':pm_year[0:3]['avg_pm'], 'asthma_count': sel_as['asthma_count']})
seven_year
# Out:
#      avg_pm  asthma_count
# 0  9.771093    397.839532
# 1  9.311493     41.619829
# 2  9.311493     42.345748

# %%
X2 = seven_year[['avg_pm']] 
X2 = sm.add_constant(X2)

y2 = seven_year['asthma_count'] 

freq_model2 = sm.GLM(y2, exog = X2, 
                  family=sm.families.Poisson())
freq_res2 = freq_model2.fit()
print(freq_res2.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           asthma_count   No. Observations:                    3
# Model:                            GLM   Df Residuals:                        1
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -9.4944
# Date:                Sat, 14 Dec 2024   Deviance:                    0.0062760
# Time:                        14:57:24   Pearson chi2:                  0.00628
# No. Iterations:                     5   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -41.8232      2.533    -16.513      0.000     -46.787     -36.859
# ...

# %%
sns.set(style="dark")
plt.style.use("ggplot")

from pymc import *
import pymc as pm
import bambi as bmb
import arviz as az

# %%
with pm.Model() as model:
    q0 = pm.Flat("q0")
    q1 = pm.Flat("q1")

    lam = pm.math.exp(q0 + q1 * three_year['avg_pm'])
    
    Y_obs = pm.Poisson("Y_obs", mu = lam, observed = three_year['asthma_count'])

    # DO NOT CHANGE THE SAMPLING ROUTINE
    trace = pm.sample(2000, chains = 4, random_seed = 0, return_inferencedata = True)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [q0, q1]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 4 seconds.

# %%
az.plot_posterior(trace, round_to=3)
plt.show()

# %%
my_model = bmb.Model('asthma_count ~ avg_pm', three_year, family = 'poisson')
my_model_samples = my_model.fit(random_seed = 0)

az.plot_posterior(my_model_samples, round_to=3)
plt.show()
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [Intercept, avg_pm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.

# %%
print(np.mean(asthma_2014_val))
print(np.mean(asthma_2015_val))
print(np.mean(asthma_2016_val))
print(np.mean(asthma_2017_val))
print(np.mean(asthma_2018_val))
print(np.mean(asthma_2019_val))
print(np.mean(asthma_2020_val))
print(np.mean(asthma_2021_val))
# Out:
# 540.4292033856111
# 372.05482449397823
# 489.7672165474981
# 396.1743715154587
# 397.8395319465077
# 41.61982872200262
# 42.34574808184138
# 41.50895856662928

# %%
print(np.var(asthma_2014_val))
print(np.var(asthma_2015_val))
print(np.var(asthma_2016_val))
print(np.var(asthma_2017_val))
print(np.var(asthma_2018_val))
print(np.var(asthma_2019_val))
print(np.var(asthma_2020_val))
print(np.var(asthma_2021_val))
# Out:
# 16951900.92151602
# 7522225.969216667
# 21359802.708582595
# 10905052.725415228
# 10718683.71811224
# 4876.138730668951
# 6324.842162228098
# 751.2404871199706

# %%
X = three_year[['avg_pm']]
X = sm.add_constant(X) 

y = three_year['asthma_count'] 


freq_model3 = sm.GLM(y, exog=X, family=sm.families.NegativeBinomial(alpha=1.0))
freq_res3 = freq_model3.fit()

print(freq_res3.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           asthma_count   No. Observations:                    3
# Model:                            GLM   Df Residuals:                        1
# Model Family:        NegativeBinomial   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21.427
# Date:                Sat, 14 Dec 2024   Deviance:                     0.037576
# Time:                        15:45:40   Pearson chi2:                   0.0372
# No. Iterations:                     3   Pseudo R-squ. (CS):            0.01157
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4778     25.254      0.059      0.953     -48.018      50.974
# ...

# %%
pm_year.iloc[3]['avg_pm']
# Out:
# 9.517064877566684

# %%
asthma_year.iloc[0]['asthma_count']
# Out:
# 540.4292033856111

# %%
year_2014 = pd.DataFrame({'avg_pm':[pm_year.iloc[3]['avg_pm']], 'asthma_count': [asthma_year.iloc[0]['asthma_count']]})
year_2014
# Out:
#      avg_pm  asthma_count
# 0  9.517065    540.429203

# %%
print(freq_res3.predict(sm.add_constant(pm_year.iloc[3])).iloc[1])
# the_pm = pm_year.iloc[3]['avg_pm']
# data_2014 = pd.DataFrame({'avg_pm': [the_pm]})
# freq_res3.predict(data_2014)
# freq_res3.predict(sm.add_constant(year_2014))
# Out:
# 476.84640024846425
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/genmod/families/links.py:527: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)

# %%
sel_as2 = asthma_year[2:5].reset_index()
five_year = pd.DataFrame({'avg_pm':pm_year[0:3]['avg_pm'], 'asthma_count': sel_as2['asthma_count']})
five_year
# Out:
#      avg_pm  asthma_count
# 0  9.771093    489.767217
# 1  9.311493    396.174372
# 2  9.311493    397.839532

# %%
X3 = five_year[['avg_pm']] 
X3 = sm.add_constant(X3)

y3 = five_year['asthma_count'] 

freq_model5 = sm.GLM(y3, exog = X3, family=sm.families.NegativeBinomial(alpha=1.0))
freq_res5 = freq_model5.fit()

print(freq_res5.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           asthma_count   No. Observations:                    3
# Model:                            GLM   Df Residuals:                        1
# Model Family:        NegativeBinomial   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -21.165
# Date:                Sat, 14 Dec 2024   Deviance:                   8.7739e-06
# Time:                        14:57:55   Pearson chi2:                 8.77e-06
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.009941
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.7298     25.256      0.068      0.945     -47.771      51.231
# ...

# %%
X2 = seven_year[['avg_pm']] 
X2 = sm.add_constant(X2)

y2 = seven_year['asthma_count'] 

freq_model4 = sm.GLM(y2, exog = X2, family=sm.families.NegativeBinomial(alpha=1.0))
freq_res4 = freq_model4.fit()

print(freq_res4.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           asthma_count   No. Observations:                    3
# Model:                            GLM   Df Residuals:                        1
# Model Family:        NegativeBinomial   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -16.485
# Date:                Sat, 14 Dec 2024   Deviance:                   0.00014601
# Time:                        14:57:58   Pearson chi2:                 0.000146
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.6908
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -41.8232     25.355     -1.650      0.099     -91.518       7.872
# ...

# %%
import pymc as pm

with pm.Model() as model:
    q0 = pm.Flat("q0")
    q1 = pm.Flat("q1")

    mu = pm.math.exp(q0 + q1 * three_year['avg_pm']) 
    alpha = pm.HalfNormal("alpha", sigma=1)
    Y_obs = pm.NegativeBinomial("Y_obs", mu=mu, alpha=alpha, observed=three_year['asthma_count'])
    
    trace = pm.sample(2000, chains=4, random_seed=0, return_inferencedata=True)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [q0, q1, alpha]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 19 seconds.
# There were 724 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
az.plot_posterior(trace, round_to=3)
plt.show()

# %%
my_model = bmb.Model('asthma_count ~ avg_pm', three_year, family='negativebinomial')

my_model_samples = my_model.fit(random_seed=0)

az.plot_posterior(my_model_samples, round_to=3)
plt.show()
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, Intercept, avg_pm]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.
# There were 59 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
# with model:  # Use your Negative Binomial model here
#     # Sample from the posterior predictive distribution
#     nb_ppc = pm.sample_posterior_predictive(trace)
    
#     # Convert `posterior_predictive` and `observed_data` to float (if needed)
#     nb_ppc.posterior_predictive['Y_obs'] = nb_ppc.posterior_predictive['Y_obs'] + 0.0
#     nb_ppc.observed_data['Y_obs'] = nb_ppc.observed_data['Y_obs'] + 0.0

# # Plot Posterior Predictive Checks
# az.plot_ppc(nb_ppc)
# plt.xlabel('Y_obs = Number of asthma cases')
# plt.title('Bayesian Negative Binomial Regression')
# plt.axis([-2, 45, -0.01, 0.2])

# plt.show()

# %%
print("Poisson AIC:", freq_res2.aic)
print("Negative Binomial AIC:", freq_res4.aic)
# Out:
# Poisson AIC: 22.988759764109147
# Negative Binomial AIC: 36.970912658392876

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Split the data into training and testing sets
X_train = three_year[['avg_pm']].values  # Predictor (PM2.5)
y_train = three_year['asthma_count'].values  # Response (asthma cases)

X_test = year_2014[['avg_pm']]
y_test = year_2014['asthma_count']

# Create and fit the k-NN regressor
k = 3  # Choose the number of neighbors (tune this parameter for optimal results)
knn_model = KNeighborsRegressor(n_neighbors=k)
knn_model.fit(X_train, y_train)

# Predict on the test set
y_pred = knn_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
# print(f"R-squared: {r2:.2f}")

# Predict for new PM2.5 values
new_data = np.array(X_test)  # Example: PM2.5 value for prediction
predicted_asthma_cases = knn_model.predict(new_data)
print(f"Predicted asthma cases for 2014 avg_pm: {predicted_asthma_cases[0]:.2f}")
# Out:
# Mean Squared Error: 5330.77
# Predicted asthma cases for 2014 avg_pm: 467.42
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(
